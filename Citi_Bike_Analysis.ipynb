# %%
import numpy as np
import pandas as pd

# %%
# These libraries will help us import JSON data:
import json
import urllib.request

# %%
import veroviz as vrv
vrv.checkVersion()
# Out:
# 'Your current installed version of veroviz is 0.3.1. You are up-to-date with the latest available version.'

# %%
# I like to use "environment" variables to store "private" stuff
# (like API keys, or paths to installed files).
# We'll need the `os` library for that:
import os

# See https://veroviz.org/documentation.html#installation for details

# %%
with urllib.request.urlopen("https://gbfs.citibikenyc.com/gbfs/es/station_status.json") as url:
    station_status_data = json.loads(url.read().decode())
station_status_data
# Out:
# {'last_updated': 1582535355,
#  'ttl': 10,
#  'data': {'stations': [{'station_id': '72',
#     'num_bikes_available': 24,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 30,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582529187,
#     'eightd_has_available_keys': False},
#    {'station_id': '79',
#     'num_bikes_available': 29,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 4,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582529079,
#     'eightd_has_available_keys': False},
#    {'station_id': '82',
#     'num_bikes_available': 25,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 2,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582526644,
#     'eightd_has_available_keys': False},
#    {'station_id': '83',
#     'num_bikes_available': 58,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 4,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582525443,
#     'eightd_has_available_keys': False},
#    {'station_id': '116',
#     'num_bikes_available': 10,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 40,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582528042,
#     'eightd_has_available_keys': False},
#    {'station_id': '119',
#     'num_bikes_available': 12,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 6,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582525506,
#     'eightd_has_available_keys': False},
#    {'station_id': '120',
#     'num_bikes_available': 1,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 16,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582525471,
#     'eightd_has_available_keys': False},
#    {'station_id': '127',
#     'num_bikes_available': 26,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 5,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582528018,
#     'eightd_has_available_keys': False},
#    {'station_id': '128',
#     'num_bikes_available': 26,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 3,
#     'num_docks_available': 0,
#     'num_docks_disabled': 1,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582533806,
#     'eightd_has_available_keys': False},
#    {'station_id': '143',
#     'num_bikes_available': 5,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 19,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582525431,
#     'eightd_has_available_keys': False},
#    {'station_id': '144',
#     'num_bikes_available': 51,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 7,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582529328,
#     'eightd_has_available_keys': False},
#    {'station_id': '146',
#     'num_bikes_available': 38,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 1,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582526646,
#     'eightd_has_available_keys': False},
#    {'station_id': '150',
#     'num_bikes_available': 24,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 30,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582535238,
#     'eightd_has_available_keys': False},
#    {'station_id': '151',
#     'num_bikes_available': 9,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 22,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582526670,
#     'eightd_has_available_keys': True},
#    {'station_id': '157',
#     'num_bikes_available': 11,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 12,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582525644,
#     'eightd_has_available_keys': False},
#    {'station_id': '161',
#     'num_bikes_available': 14,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 21,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582527953,
#     'eightd_has_available_keys': False},
#    {'station_id': '164',
#     'num_bikes_available': 4,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 41,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582531687,
#     'eightd_has_available_keys': False},
#    {'station_id': '167',
#     'num_bikes_available': 21,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 23,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582529128,
#     'eightd_has_available_keys': False},
#    {'station_id': '168',
#     'num_bikes_available': 8,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 38,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582529235,
#     'eightd_has_available_keys': False},
#    {'station_id': '173',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 69,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582531646,
#     'eightd_has_available_keys': False},
#    {'station_id': '174',
#     'num_bikes_available': 5,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 24,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582528052,
#     'eightd_has_available_keys': False},
#    {'station_id': '195',
#     'num_bikes_available': 17,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 28,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582534339,
#     'eightd_has_available_keys': False},
#    {'station_id': '212',
#     'num_bikes_available': 28,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 32,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582529090,
#     'eightd_has_available_keys': False},
#    {'station_id': '216',
#     'num_bikes_available': 4,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 19,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582528227,
#     'eightd_has_available_keys': False},
#    {'station_id': '217',
#     'num_bikes_available': 30,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 9,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582525553,
#     'eightd_has_available_keys': True},
#    {'station_id': '223',
#     'num_bikes_available': 31,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 2,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582526636,
#     'eightd_has_available_keys': False},
#    {'station_id': '224',
#     'num_bikes_available': 24,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 7,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582533321,
#     'eightd_has_available_keys': True},
#    {'station_id': '228',
#     'num_bikes_available': 8,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 47,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582529206,
#     'eightd_has_available_keys': False},
#    {'station_id': '229',
#     'num_bikes_available': 6,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 17,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582529843,
#     'eightd_has_available_keys': False},
#    {'station_id': '236',
#     'num_bikes_available': 39,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 3,
#     'num_docks_available': 5,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582531515,
#     'eightd_has_available_keys': False},
#    {'station_id': '237',
#     'num_bikes_available': 31,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 8,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582528959,
#     'eightd_has_available_keys': False},
#    {'station_id': '238',
#     'num_bikes_available': 30,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 0,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582527964,
#     'eightd_has_available_keys': False},
#    {'station_id': '239',
#     'num_bikes_available': 6,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 25,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582525477,
#     'eightd_has_available_keys': False},
#    {'station_id': '241',
#     'num_bikes_available': 6,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 17,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582528314,
#     'eightd_has_available_keys': False},
#    {'station_id': '242',
#     'num_bikes_available': 44,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 2,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582529384,
#     'eightd_has_available_keys': False},
#    {'station_id': '244',
#     'num_bikes_available': 16,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 15,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582528939,
#     'eightd_has_available_keys': False},
#    {'station_id': '245',
#     'num_bikes_available': 18,
#     'num_ebikes_available': 2,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 5,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582529083,
#     'eightd_has_available_keys': True},
#    {'station_id': '247',
#     'num_bikes_available': 55,
#     'num_ebikes_available': 2,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 0,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582535314,
#     'eightd_has_available_keys': False},
#    {'station_id': '248',
#     'num_bikes_available': 5,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 18,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582534462,
#     'eightd_has_available_keys': False},
#    {'station_id': '249',
#     'num_bikes_available': 24,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 2,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582529095,
#     'eightd_has_available_keys': False},
#    {'station_id': '250',
#     'num_bikes_available': 17,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 23,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582535199,
#     'eightd_has_available_keys': False},
#    {'station_id': '251',
#     'num_bikes_available': 22,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 5,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582528048,
#     'eightd_has_available_keys': False},
#    {'station_id': '252',
#     'num_bikes_available': 27,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 5,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582527988,
#     'eightd_has_available_keys': False},
#    {'station_id': '254',
#     'num_bikes_available': 14,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 43,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582527880,
#     'eightd_has_available_keys': False},
#    {'station_id': '257',
#     'num_bikes_available': 31,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 7,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582529262,
#     'eightd_has_available_keys': False},
#    {'station_id': '258',
#     'num_bikes_available': 13,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 10,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582525628,
#     'eightd_has_available_keys': False},
#    {'station_id': '259',
#     'num_bikes_available': 36,
#     'num_ebikes_available': 3,
#     'num_bikes_disabled': 3,
#     'num_docks_available': 0,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582532439,
#     'eightd_has_available_keys': True},
#    {'station_id': '260',
#     'num_bikes_available': 26,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 7,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582526790,
#     'eightd_has_available_keys': False},
#    {'station_id': '261',
#     'num_bikes_available': 8,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 19,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582525520,
#     'eightd_has_available_keys': False},
#    {'station_id': '262',
#     'num_bikes_available': 17,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 6,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582528027,
#     'eightd_has_available_keys': False},
#    {'station_id': '264',
#     'num_bikes_available': 23,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 3,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582526815,
#     'eightd_has_available_keys': False},
#    {'station_id': '265',
#     'num_bikes_available': 32,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 2,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582526838,
#     'eightd_has_available_keys': False},
#    {'station_id': '267',
#     'num_bikes_available': 5,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 73,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582529090,
#     'eightd_has_available_keys': False},
#    {'station_id': '268',
#     'num_bikes_available': 12,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 14,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582529211,
#     'eightd_has_available_keys': False},
#    {'station_id': '270',
#     'num_bikes_available': 13,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 10,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582529126,
#     'eightd_has_available_keys': False},
#    {'station_id': '274',
#     'num_bikes_available': 14,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 17,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582534806,
#     'eightd_has_available_keys': False},
#    {'station_id': '275',
#     'num_bikes_available': 2,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 16,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582528588,
#     'eightd_has_available_keys': False},
#    {'station_id': '276',
#     'num_bikes_available': 24,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 1,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582526787,
#     'eightd_has_available_keys': False},
#    {'station_id': '278',
#     'num_bikes_available': 16,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 3,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582525614,
#     'eightd_has_available_keys': False},
#    {'station_id': '280',
#     'num_bikes_available': 31,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 27,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582527959,
#     'eightd_has_available_keys': False},
#    {'station_id': '281',
#     'num_bikes_available': 17,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 48,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582532720,
#     'eightd_has_available_keys': False},
#    {'station_id': '282',
#     'num_bikes_available': 12,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 15,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582527874,
#     'eightd_has_available_keys': False},
#    {'station_id': '284',
#     'num_bikes_available': 38,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 4,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582531141,
#     'eightd_has_available_keys': False},
#    {'station_id': '285',
#     'num_bikes_available': 4,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 3,
#     'num_docks_available': 46,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582532834,
#     'eightd_has_available_keys': True},
#    {'station_id': '289',
#     'num_bikes_available': 4,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 15,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582526760,
#     'eightd_has_available_keys': False},
#    {'station_id': '291',
#     'num_bikes_available': 16,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 4,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582529250,
#     'eightd_has_available_keys': False},
#    {'station_id': '293',
#     'num_bikes_available': 16,
#     'num_ebikes_available': 2,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 38,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582534034,
#     'eightd_has_available_keys': False},
#    {'station_id': '295',
#     'num_bikes_available': 24,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 0,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582526750,
#     'eightd_has_available_keys': False},
#    {'station_id': '297',
#     'num_bikes_available': 3,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 24,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582527877,
#     'eightd_has_available_keys': False},
#    {'station_id': '298',
#     'num_bikes_available': 21,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 14,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582527253,
#     'eightd_has_available_keys': False},
#    {'station_id': '301',
#     'num_bikes_available': 43,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 13,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582529173,
#     'eightd_has_available_keys': False},
#    {'station_id': '302',
#     'num_bikes_available': 19,
#     'num_ebikes_available': 2,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 4,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582528644,
#     'eightd_has_available_keys': False},
#    {'station_id': '303',
#     'num_bikes_available': 56,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 3,
#     'num_docks_available': 8,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582534186,
#     'eightd_has_available_keys': False},
#    {'station_id': '304',
#     'num_bikes_available': 33,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 0,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582530675,
#     'eightd_has_available_keys': True},
#    {'station_id': '305',
#     'num_bikes_available': 14,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 19,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582531882,
#     'eightd_has_available_keys': False},
#    {'station_id': '307',
#     'num_bikes_available': 13,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 16,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582526777,
#     'eightd_has_available_keys': False},
#    {'station_id': '308',
#     'num_bikes_available': 24,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 2,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582529086,
#     'eightd_has_available_keys': False},
#    {'station_id': '309',
#     'num_bikes_available': 27,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 12,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582529060,
#     'eightd_has_available_keys': False},
#    {'station_id': '310',
#     'num_bikes_available': 20,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 16,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582525555,
#     'eightd_has_available_keys': False},
#    {'station_id': '311',
#     'num_bikes_available': 9,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 22,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582526814,
#     'eightd_has_available_keys': False},
#    {'station_id': '312',
#     'num_bikes_available': 11,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 19,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582535310,
#     'eightd_has_available_keys': False},
#    {'station_id': '313',
#     'num_bikes_available': 8,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 14,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582525440,
#     'eightd_has_available_keys': False},
#    {'station_id': '315',
#     'num_bikes_available': 25,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 3,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582526869,
#     'eightd_has_available_keys': True},
#    {'station_id': '316',
#     'num_bikes_available': 22,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 20,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582526816,
#     'eightd_has_available_keys': False},
#    {'station_id': '317',
#     'num_bikes_available': 38,
#     'num_ebikes_available': 2,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 16,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582529148,
#     'eightd_has_available_keys': False},
#    {'station_id': '319',
#     'num_bikes_available': 4,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 28,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582529065,
#     'eightd_has_available_keys': False},
#    {'station_id': '320',
#     'num_bikes_available': 32,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 7,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582529179,
#     'eightd_has_available_keys': False},
#    {'station_id': '321',
#     'num_bikes_available': 7,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 20,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582526650,
#     'eightd_has_available_keys': True},
#    {'station_id': '323',
#     'num_bikes_available': 20,
#     'num_ebikes_available': 2,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 19,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582526511,
#     'eightd_has_available_keys': False},
#    {'station_id': '324',
#     'num_bikes_available': 12,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 39,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582534594,
#     'eightd_has_available_keys': False},
#    {'station_id': '325',
#     'num_bikes_available': 20,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 14,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582525626,
#     'eightd_has_available_keys': False},
#    {'station_id': '326',
#     'num_bikes_available': 20,
#     'num_ebikes_available': 2,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 20,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582529926,
#     'eightd_has_available_keys': False},
#    {'station_id': '327',
#     'num_bikes_available': 37,
#     'num_ebikes_available': 2,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 1,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582533495,
#     'eightd_has_available_keys': True},
#    {'station_id': '328',
#     'num_bikes_available': 21,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 1,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582533231,
#     'eightd_has_available_keys': False},
#    {'station_id': '330',
#     'num_bikes_available': 31,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 7,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582529245,
#     'eightd_has_available_keys': False},
#    {'station_id': '331',
#     'num_bikes_available': 19,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 7,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582526677,
#     'eightd_has_available_keys': False},
#    {'station_id': '332',
#     'num_bikes_available': 27,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 7,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582526795,
#     'eightd_has_available_keys': False},
#    {'station_id': '334',
#     'num_bikes_available': 22,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 9,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582526741,
#     'eightd_has_available_keys': False},
#    {'station_id': '335',
#     'num_bikes_available': 12,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 14,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582531013,
#     'eightd_has_available_keys': False},
#    {'station_id': '336',
#     'num_bikes_available': 28,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 7,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582527901,
#     'eightd_has_available_keys': False},
#    {'station_id': '337',
#     'num_bikes_available': 28,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 9,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582526827,
#     'eightd_has_available_keys': False},
#    {'station_id': '339',
#     'num_bikes_available': 13,
#     'num_ebikes_available': 2,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 17,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582532374,
#     'eightd_has_available_keys': False},
#    {'station_id': '340',
#     'num_bikes_available': 12,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 15,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582535260,
#     'eightd_has_available_keys': True},
#    {'station_id': '341',
#     'num_bikes_available': 10,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 9,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582528049,
#     'eightd_has_available_keys': False},
#    {'station_id': '342',
#     'num_bikes_available': 24,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 4,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582526733,
#     'eightd_has_available_keys': False},
#    {'station_id': '343',
#     'num_bikes_available': 10,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 13,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582525429,
#     'eightd_has_available_keys': False},
#    {'station_id': '344',
#     'num_bikes_available': 2,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 21,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582525461,
#     'eightd_has_available_keys': False},
#    {'station_id': '346',
#     'num_bikes_available': 26,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 0,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582528070,
#     'eightd_has_available_keys': False},
#    {'station_id': '347',
#     'num_bikes_available': 8,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 27,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582529274,
#     'eightd_has_available_keys': False},
#    {'station_id': '349',
#     'num_bikes_available': 5,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 56,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582527394,
#     'eightd_has_available_keys': False},
#    {'station_id': '350',
#     'num_bikes_available': 16,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 12,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582529705,
#     'eightd_has_available_keys': False},
#    {'station_id': '351',
#     'num_bikes_available': 36,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 1,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582526788,
#     'eightd_has_available_keys': False},
#    {'station_id': '353',
#     'num_bikes_available': 2,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 25,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582533993,
#     'eightd_has_available_keys': False},
#    {'station_id': '354',
#     'num_bikes_available': 12,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 11,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582533907,
#     'eightd_has_available_keys': False},
#    {'station_id': '355',
#     'num_bikes_available': 28,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 15,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582533900,
#     'eightd_has_available_keys': False},
#    {'station_id': '356',
#     'num_bikes_available': 12,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 11,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582527920,
#     'eightd_has_available_keys': False},
#    {'station_id': '358',
#     'num_bikes_available': 47,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 2,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582535221,
#     'eightd_has_available_keys': False},
#    {'station_id': '359',
#     'num_bikes_available': 10,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 54,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582527990,
#     'eightd_has_available_keys': False},
#    {'station_id': '360',
#     'num_bikes_available': 16,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 23,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582526755,
#     'eightd_has_available_keys': False},
#    {'station_id': '361',
#     'num_bikes_available': 25,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 18,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582530627,
#     'eightd_has_available_keys': False},
#    {'station_id': '362',
#     'num_bikes_available': 7,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 50,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582532696,
#     'eightd_has_available_keys': False},
#    {'station_id': '363',
#     'num_bikes_available': 44,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 5,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582527196,
#     'eightd_has_available_keys': False},
#    {'station_id': '364',
#     'num_bikes_available': 14,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 13,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582528820,
#     'eightd_has_available_keys': False},
#    {'station_id': '366',
#     'num_bikes_available': 11,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 22,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582527594,
#     'eightd_has_available_keys': False},
#    {'station_id': '367',
#     'num_bikes_available': 6,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 28,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582529047,
#     'eightd_has_available_keys': False},
#    {'station_id': '368',
#     'num_bikes_available': 34,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 4,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582528024,
#     'eightd_has_available_keys': True},
#    {'station_id': '369',
#     'num_bikes_available': 58,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 2,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582527917,
#     'eightd_has_available_keys': False},
#    {'station_id': '372',
#     'num_bikes_available': 2,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 25,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582525459,
#     'eightd_has_available_keys': False},
#    {'station_id': '373',
#     'num_bikes_available': 4,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 15,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582525635,
#     'eightd_has_available_keys': False},
#    {'station_id': '376',
#     'num_bikes_available': 30,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 13,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582535178,
#     'eightd_has_available_keys': False},
#    {'station_id': '377',
#     'num_bikes_available': 23,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 24,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582526743,
#     'eightd_has_available_keys': False},
#    {'station_id': '379',
#     'num_bikes_available': 2,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 38,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582528033,
#     'eightd_has_available_keys': False},
#    {'station_id': '380',
#     'num_bikes_available': 38,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 4,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582532000,
#     'eightd_has_available_keys': False},
#    {'station_id': '383',
#     'num_bikes_available': 31,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 7,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582534126,
#     'eightd_has_available_keys': False},
#    {'station_id': '385',
#     'num_bikes_available': 11,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 18,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582529107,
#     'eightd_has_available_keys': False},
#    {'station_id': '386',
#     'num_bikes_available': 17,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 24,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582510148,
#     'eightd_has_available_keys': False},
#    {'station_id': '387',
#     'num_bikes_available': 27,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 3,
#     'num_docks_available': 9,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582526785,
#     'eightd_has_available_keys': False},
#    {'station_id': '388',
#     'num_bikes_available': 11,
#     'num_ebikes_available': 2,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 23,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582527187,
#     'eightd_has_available_keys': False},
#    {'station_id': '389',
#     'num_bikes_available': 19,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 8,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582534153,
#     'eightd_has_available_keys': False},
#    {'station_id': '390',
#     'num_bikes_available': 3,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 28,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582533742,
#     'eightd_has_available_keys': False},
#    {'station_id': '391',
#     'num_bikes_available': 4,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 11,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582530474,
#     'eightd_has_available_keys': False},
#    {'station_id': '392',
#     'num_bikes_available': 13,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 22,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582525578,
#     'eightd_has_available_keys': False},
#    {'station_id': '393',
#     'num_bikes_available': 16,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 20,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582529072,
#     'eightd_has_available_keys': False},
#    {'station_id': '394',
#     'num_bikes_available': 31,
#     'num_ebikes_available': 2,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 2,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582531382,
#     'eightd_has_available_keys': False},
#    {'station_id': '396',
#     'num_bikes_available': 1,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 24,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582525454,
#     'eightd_has_available_keys': False},
#    {'station_id': '397',
#     'num_bikes_available': 1,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 26,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582525581,
#     'eightd_has_available_keys': False},
#    {'station_id': '398',
#     'num_bikes_available': 9,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 22,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582525566,
#     'eightd_has_available_keys': False},
#    {'station_id': '399',
#     'num_bikes_available': 7,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 19,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582525594,
#     'eightd_has_available_keys': False},
#    {'station_id': '400',
#     'num_bikes_available': 4,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 11,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582528527,
#     'eightd_has_available_keys': False},
#    {'station_id': '401',
#     'num_bikes_available': 28,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 12,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582526712,
#     'eightd_has_available_keys': False},
#    {'station_id': '402',
#     'num_bikes_available': 3,
#     'num_ebikes_available': 2,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 36,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582528465,
#     'eightd_has_available_keys': False},
#    {'station_id': '403',
#     'num_bikes_available': 18,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 13,
#     'num_docks_disabled': 0,
# ...
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582497190,
#     'eightd_has_available_keys': False},
#    {'station_id': '3862',
#     'num_bikes_available': 1,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 17,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582506405,
#     'eightd_has_available_keys': False},
#    {'station_id': '3863',
#     'num_bikes_available': 6,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 12,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582533245,
#     'eightd_has_available_keys': False},
#    {'station_id': '3864',
#     'num_bikes_available': 5,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 25,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582487842,
#     'eightd_has_available_keys': False},
#    {'station_id': '3865',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 24,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582510712,
#     'eightd_has_available_keys': False},
#    {'station_id': '3866',
#     'num_bikes_available': 1,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 31,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582512410,
#     'eightd_has_available_keys': False},
#    {'station_id': '3867',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 29,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582510790,
#     'eightd_has_available_keys': False},
#    {'station_id': '3868',
#     'num_bikes_available': 3,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 16,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582507783,
#     'eightd_has_available_keys': False},
#    {'station_id': '3869',
#     'num_bikes_available': 1,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 23,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582516145,
#     'eightd_has_available_keys': False},
#    {'station_id': '3870',
#     'num_bikes_available': 1,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 19,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582518421,
#     'eightd_has_available_keys': False},
#    {'station_id': '3871',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 30,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582484798,
#     'eightd_has_available_keys': False},
#    {'station_id': '3872',
#     'num_bikes_available': 4,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 15,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582519586,
#     'eightd_has_available_keys': False},
#    {'station_id': '3873',
#     'num_bikes_available': 1,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 16,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582497059,
#     'eightd_has_available_keys': False},
#    {'station_id': '3874',
#     'num_bikes_available': 1,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 15,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582519452,
#     'eightd_has_available_keys': False},
#    {'station_id': '3875',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 15,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582451087,
#     'eightd_has_available_keys': False},
#    {'station_id': '3876',
#     'num_bikes_available': 9,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 12,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582517245,
#     'eightd_has_available_keys': False},
#    {'station_id': '3877',
#     'num_bikes_available': 5,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 20,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582501506,
#     'eightd_has_available_keys': False},
#    {'station_id': '3878',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 19,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582518998,
#     'eightd_has_available_keys': False},
#    {'station_id': '3879',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 25,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582515028,
#     'eightd_has_available_keys': False},
#    {'station_id': '3880',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 27,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582495183,
#     'eightd_has_available_keys': False},
#    {'station_id': '3881',
#     'num_bikes_available': 23,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 16,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582533871,
#     'eightd_has_available_keys': False},
#    {'station_id': '3882',
#     'num_bikes_available': 2,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 12,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582534287,
#     'eightd_has_available_keys': False},
#    {'station_id': '3883',
#     'num_bikes_available': 2,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 16,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582507471,
#     'eightd_has_available_keys': False},
#    {'station_id': '3884',
#     'num_bikes_available': 10,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 13,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582490993,
#     'eightd_has_available_keys': False},
#    {'station_id': '3885',
#     'num_bikes_available': 1,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 18,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582519265,
#     'eightd_has_available_keys': False},
#    {'station_id': '3886',
#     'num_bikes_available': 2,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 18,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582492968,
#     'eightd_has_available_keys': False},
#    {'station_id': '3887',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 20,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582506094,
#     'eightd_has_available_keys': False},
#    {'station_id': '3888',
#     'num_bikes_available': 2,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 17,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582523859,
#     'eightd_has_available_keys': False},
#    {'station_id': '3890',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 29,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582506705,
#     'eightd_has_available_keys': False},
#    {'station_id': '3891',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 20,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582481833,
#     'eightd_has_available_keys': False},
#    {'station_id': '3892',
#     'num_bikes_available': 4,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 15,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582533913,
#     'eightd_has_available_keys': False},
#    {'station_id': '3893',
#     'num_bikes_available': 3,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 22,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582522213,
#     'eightd_has_available_keys': False},
#    {'station_id': '3895',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 25,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582495119,
#     'eightd_has_available_keys': False},
#    {'station_id': '3896',
#     'num_bikes_available': 1,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 21,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582534013,
#     'eightd_has_available_keys': False},
#    {'station_id': '3897',
#     'num_bikes_available': 2,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 15,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582531193,
#     'eightd_has_available_keys': False},
#    {'station_id': '3898',
#     'num_bikes_available': 19,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 37,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582531620,
#     'eightd_has_available_keys': False},
#    {'station_id': '3899',
#     'num_bikes_available': 8,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 10,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582531742,
#     'eightd_has_available_keys': False},
#    {'station_id': '3900',
#     'num_bikes_available': 1,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 29,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582507285,
#     'eightd_has_available_keys': False},
#    {'station_id': '3901',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 17,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582499112,
#     'eightd_has_available_keys': False},
#    {'station_id': '3902',
#     'num_bikes_available': 3,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 16,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582494640,
#     'eightd_has_available_keys': False},
#    {'station_id': '3903',
#     'num_bikes_available': 3,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 14,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582524823,
#     'eightd_has_available_keys': False},
#    {'station_id': '3905',
#     'num_bikes_available': 15,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 12,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582534058,
#     'eightd_has_available_keys': False},
#    {'station_id': '3907',
#     'num_bikes_available': 4,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 13,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582513522,
#     'eightd_has_available_keys': False},
#    {'station_id': '3909',
#     'num_bikes_available': 2,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 17,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582497763,
#     'eightd_has_available_keys': False},
#    {'station_id': '3910',
#     'num_bikes_available': 1,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 16,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582513586,
#     'eightd_has_available_keys': False},
#    {'station_id': '3911',
#     'num_bikes_available': 22,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 0,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582532665,
#     'eightd_has_available_keys': False},
#    {'station_id': '3913',
#     'num_bikes_available': 18,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 1,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582529586,
#     'eightd_has_available_keys': False},
#    {'station_id': '3914',
#     'num_bikes_available': 3,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 36,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582531657,
#     'eightd_has_available_keys': False},
#    {'station_id': '3916',
#     'num_bikes_available': 40,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 4,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582534128,
#     'eightd_has_available_keys': True},
#    {'station_id': '3917',
#     'num_bikes_available': 5,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 26,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582525557,
#     'eightd_has_available_keys': False},
#    {'station_id': '3918',
#     'num_bikes_available': 28,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 2,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582534065,
#     'eightd_has_available_keys': False}]}}

# %%
# FIXME [DONE]

# It would be better (in my opinion) to color-code the nodes 
# based on Station STATUS.  For example:
# - green  --> bikes and docks are available
# - red    --> no bikes available
# - yellow --> no docks available

# %%
# Convert the JSON data into a Pandas dataframe:
station_status_df = pd.DataFrame(station_status_data['data']['stations'])
station_status_df.loc[(station_status_df['num_bikes_available']>0) & 
                      (station_status_df['num_docks_available']>0),'lcolor'] = 'green'
station_status_df.loc[(station_status_df['num_bikes_available']==0),'lcolor'] = 'red'
station_status_df.loc[(station_status_df['num_docks_available']==0),'lcolor'] = 'orange'
station_status_df.loc[(station_status_df['num_bikes_available']>0) & 
                      (station_status_df['num_docks_available']>0),'ccolor'] = 'Cesium.Color.GREEN'
station_status_df.loc[(station_status_df['num_bikes_available']==0),'ccolor'] = 'Cesium.Color.RED'
station_status_df.loc[(station_status_df['num_docks_available']==0),'ccolor'] = 'Cesium.Color.ORANGE'
station_status_df.head()
# Out:
#   station_id  num_bikes_available  num_ebikes_available  num_bikes_disabled  \
# 0         72                   24                     0                   1
# 1         79                   29                     0                   0
# 2         82                   25                     0                   0
# 3         83                   58                     0                   0
# 4        116                   10                     0                   0
#
#    num_docks_available  num_docks_disabled  is_installed  is_renting  \
# 0                   30                   0             1           1
# 1                    4                   0             1           1
# 2                    2                   0             1           1
# 3                    4                   0             1           1
# 4                   40                   0             1           1
#
#    is_returning  last_reported  eightd_has_available_keys lcolor  \
# 0             1     1582529187                      False  green
# 1             1     1582529079                      False  green
# 2             1     1582526644                      False  green
# 3             1     1582525443                      False  green
# 4             1     1582528042                      False  green
#
#                ccolor
# 0  Cesium.Color.GREEN
# 1  Cesium.Color.GREEN
# 2  Cesium.Color.GREEN
# 3  Cesium.Color.GREEN
# 4  Cesium.Color.GREEN

# %%
station_status_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 935 entries, 0 to 934
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   station_id                 935 non-null    object
#  1   num_bikes_available        935 non-null    int64
#  2   num_ebikes_available       935 non-null    int64
#  3   num_bikes_disabled         935 non-null    int64
#  4   num_docks_available        935 non-null    int64
#  5   num_docks_disabled         935 non-null    int64
#  6   is_installed               935 non-null    int64
#  7   is_renting                 935 non-null    int64
#  8   is_returning               935 non-null    int64
#  9   last_reported              935 non-null    int64
#  10  eightd_has_available_keys  935 non-null    bool
#  11  lcolor                     935 non-null    object
#  12  ccolor                     935 non-null    object
# dtypes: bool(1), int64(9), object(3)
# memory usage: 88.7+ KB

# %%
with urllib.request.urlopen("https://gbfs.citibikenyc.com/gbfs/en/station_information.json") as url:
    station_info_data = json.loads(url.read().decode())
station_info_data
# Out:
# {'last_updated': 1582535355,
#  'ttl': 10,
#  'data': {'stations': [{'station_id': '72',
#     'external_id': '66db237e-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'W 52 St & 11 Ave',
#     'short_name': '6926.01',
#     'lat': 40.76727216,
#     'lon': -73.99392888,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 55,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=72',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '79',
#     'external_id': '66db269c-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Franklin St & W Broadway',
#     'short_name': '5430.08',
#     'lat': 40.71911552,
#     'lon': -74.00666661,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 33,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=79',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '82',
#     'external_id': '66db277a-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'St James Pl & Pearl St',
#     'short_name': '5167.06',
#     'lat': 40.71117416,
#     'lon': -74.00016545,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 27,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=82',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '83',
#     'external_id': '66db281e-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Atlantic Ave & Fort Greene Pl',
#     'short_name': '4354.07',
#     'lat': 40.68382604,
#     'lon': -73.97632328,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 62,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=83',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '116',
#     'external_id': '66db28b5-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'W 17 St & 8 Ave',
#     'short_name': '6148.02',
#     'lat': 40.74177603,
#     'lon': -74.00149746,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 50,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=116',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '119',
#     'external_id': '66db2953-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Park Ave & St Edwards St',
#     'short_name': '4700.06',
#     'lat': 40.69608941,
#     'lon': -73.97803415,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 19,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=119',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '120',
#     'external_id': '66db29e6-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Lexington Ave & Classon Ave',
#     'short_name': '4452.03',
#     'lat': 40.68676793,
#     'lon': -73.95928168,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 19,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=120',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '127',
#     'external_id': '66db2a71-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Barrow St & Hudson St',
#     'short_name': '5805.05',
#     'lat': 40.73172428,
#     'lon': -74.00674436,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 31,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=127',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '128',
#     'external_id': '66db2afe-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'MacDougal St & Prince St',
#     'short_name': '5687.04',
#     'lat': 40.72710258,
#     'lon': -74.00297088,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 30,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=128',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '143',
#     'external_id': '66db2d2b-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Clinton St & Joralemon St',
#     'short_name': '4605.04',
#     'lat': 40.69239502,
#     'lon': -73.99337909,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 24,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=143',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '144',
#     'external_id': '66db2db5-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Nassau St & Navy St',
#     'short_name': '4812.02',
#     'lat': 40.69839895,
#     'lon': -73.98068914,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 58,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=144',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '146',
#     'external_id': '66db2e3a-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Hudson St & Reade St',
#     'short_name': '5359.10',
#     'lat': 40.71625008,
#     'lon': -74.0091059,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 39,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=146',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '150',
#     'external_id': '66db2f4c-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'E 2 St & Avenue C',
#     'short_name': '5476.03',
#     'lat': 40.7208736,
#     'lon': -73.98085795,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 54,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=150',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '151',
#     'external_id': '66db2fd0-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Cleveland Pl & Spring St',
#     'short_name': '5492.05',
#     'lat': 40.722103786686034,
#     'lon': -73.99724900722504,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 33,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=151',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': True,
#     'has_kiosk': True},
#    {'station_id': '157',
#     'external_id': '66db316a-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Henry St & Atlantic Ave',
#     'short_name': '4531.05',
#     'lat': 40.69089272,
#     'lon': -73.99612349,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 23,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=157',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '161',
#     'external_id': '66db3273-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'LaGuardia Pl & W 3 St',
#     'short_name': '5721.14',
#     'lat': 40.72917025,
#     'lon': -73.99810231,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 35,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=161',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '164',
#     'external_id': '66db32fb-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'E 47 St & 2 Ave',
#     'short_name': '6498.10',
#     'lat': 40.75323098,
#     'lon': -73.97032517,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 47,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=164',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '167',
#     'external_id': '66db337f-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'E 39 St & 3 Ave',
#     'short_name': '6389.03',
#     'lat': 40.7489006,
#     'lon': -73.97604882,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 45,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=167',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '168',
#     'external_id': '66db33fc-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'W 18 St & 6 Ave',
#     'short_name': '6064.08',
#     'lat': 40.73971301,
#     'lon': -73.99456405,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 47,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=168',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '173',
#     'external_id': '66db347b-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Broadway & W 49 St',
#     'short_name': '6708.02',
#     'lat': 40.76068327096592,
#     'lon': -73.9845272898674,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 70,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=173',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '174',
#     'external_id': '66db34fc-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'E 25 St & 1 Ave',
#     'short_name': '6004.07',
#     'lat': 40.7381765,
#     'lon': -73.97738662,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 30,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=174',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '195',
#     'external_id': '66db3583-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Liberty St & Broadway',
#     'short_name': '5105.01',
#     'lat': 40.70905623,
#     'lon': -74.01043382,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 45,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=195',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '212',
#     'external_id': '66db3606-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'W 16 St & The High Line',
#     'short_name': '6233.05',
#     'lat': 40.74334935,
#     'lon': -74.00681753,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 60,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=212',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '216',
#     'external_id': '66db3687-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Columbia Heights & Cranberry St',
#     'short_name': '4829.01',
#     'lat': 40.70037867,
#     'lon': -73.99548059,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 23,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=216',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '217',
#     'external_id': '66db3708-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Old Fulton St',
#     'short_name': '4903.08',
#     'lat': 40.70277159,
#     'lon': -73.99383605,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 39,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=217',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': True,
#     'has_kiosk': True},
#    {'station_id': '223',
#     'external_id': '66db3816-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'W 13 St & 7 Ave',
#     'short_name': '6030.04',
#     'lat': 40.73781509,
#     'lon': -73.99994661,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 33,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=223',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '224',
#     'external_id': '66db3898-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Spruce St & Nassau St',
#     'short_name': '5137.10',
#     'lat': 40.71146364,
#     'lon': -74.00552427,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 31,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=224',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': True,
#     'has_kiosk': True},
#    {'station_id': '228',
#     'external_id': '66db3997-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'E 48 St & 3 Ave',
#     'short_name': '6541.03',
#     'lat': 40.7546011026,
#     'lon': -73.971878855,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 55,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=228',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '229',
#     'external_id': '66db3a1e-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Great Jones St',
#     'short_name': '5636.11',
#     'lat': 40.72743423,
#     'lon': -73.99379025,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 23,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=229',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '236',
#     'external_id': '66db3ba0-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'St Marks Pl & 2 Ave',
#     'short_name': '5669.10',
#     'lat': 40.7284186,
#     'lon': -73.98713956,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 47,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=236',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '237',
#     'external_id': '66db3c29-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'E 11 St & 2 Ave',
#     'short_name': '5746.04',
#     'lat': 40.73047309,
#     'lon': -73.98672378,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 39,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=237',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '238',
#     'external_id': '66db3cab-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Bank St & Washington St',
#     'short_name': '5964.01',
#     'lat': 40.7361967,
#     'lon': -74.00859207,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 31,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=238',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '239',
#     'external_id': '66db3d2a-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Willoughby St & Fleet St',
#     'short_name': '4628.05',
#     'lat': 40.69196566,
#     'lon': -73.9813018,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 31,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=239',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '241',
#     'external_id': '66db3da9-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'DeKalb Ave & S Portland Ave',
#     'short_name': '4546.04',
#     'lat': 40.68981035,
#     'lon': -73.97493121,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 23,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=241',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '242',
#     'external_id': '66db3e32-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Carlton Ave & Flushing Ave',
#     'short_name': '4732.08',
#     'lat': 40.697787,
#     'lon': -73.973736,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 46,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=242',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '244',
#     'external_id': '66db3f01-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Willoughby Ave & Hall St',
#     'short_name': '4611.03',
#     'lat': 40.69196035,
#     'lon': -73.96536851,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 31,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=244',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '245',
#     'external_id': '66db3f62-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Myrtle Ave & St Edwards St',
#     'short_name': '4659.02',
#     'lat': 40.69327018,
#     'lon': -73.97703874,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 23,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=245',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': True,
#     'has_kiosk': True},
#    {'station_id': '247',
#     'external_id': '66db3fc9-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Perry St & Bleecker St',
#     'short_name': '5922.07',
#     'lat': 40.73535398,
#     'lon': -74.00483091,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 55,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=247',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '248',
#     'external_id': '66db402c-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Laight St & Hudson St',
#     'short_name': '5539.06',
#     'lat': 40.72185379,
#     'lon': -74.00771779,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 23,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=248',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '249',
#     'external_id': '66db408f-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Harrison St & Hudson St',
#     'short_name': '5400.05',
#     'lat': 40.71870987,
#     'lon': -74.0090009,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 27,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=249',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '250',
#     'external_id': '66db40ef-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Lafayette St & Jersey St',
#     'short_name': '5561.06',
#     'lat': 40.72456089,
#     'lon': -73.99565293,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 40,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=250',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '251',
#     'external_id': '66db4158-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Mott St & Prince St',
#     'short_name': '5561.04',
#     'lat': 40.72317958,
#     'lon': -73.99480012,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 27,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=251',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '252',
#     'external_id': '66db41bf-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'MacDougal St & Washington Sq',
#     'short_name': '5797.01',
#     'lat': 40.73226398,
#     'lon': -73.99852205,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 33,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=252',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '254',
#     'external_id': '66db4282-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'W 11 St & 6 Ave',
#     'short_name': '5914.03',
#     'lat': 40.73532427,
#     'lon': -73.99800419,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 59,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=254',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '257',
#     'external_id': '66db4351-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Lispenard St & Broadway',
#     'short_name': '5391.06',
#     'lat': 40.71939226,
#     'lon': -74.00247214,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 39,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=257',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '258',
#     'external_id': '66db43b5-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'DeKalb Ave & Vanderbilt Ave',
#     'short_name': '4461.04',
#     'lat': 40.68940747,
#     'lon': -73.96885458,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 23,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=258',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '259',
#     'external_id': '66db4417-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'South St & Whitehall St',
#     'short_name': '4846.01',
#     'lat': 40.70122128,
#     'lon': -74.01234218,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 39,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=259',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': True,
#     'has_kiosk': True},
#    {'station_id': '260',
#     'external_id': '66db447a-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Broad St & Bridge St',
#     'short_name': '4962.08',
#     'lat': 40.70365182,
#     'lon': -74.01167797,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 33,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=260',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '261',
#     'external_id': '66db44e5-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Johnson St & Gold St',
#     'short_name': '4668.08',
#     'lat': 40.69474881,
#     'lon': -73.98362464,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 27,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=261',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '262',
#     'external_id': '66db4549-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Washington Park',
#     'short_name': '4546.05',
#     'lat': 40.6917823,
#     'lon': -73.9737299,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 24,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=262',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '264',
#     'external_id': '66db460d-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Maiden Ln & Pearl St',
#     'short_name': '5065.10',
#     'lat': 40.70706456,
#     'lon': -74.00731853,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 27,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=264',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '265',
#     'external_id': '66db4671-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Stanton St & Chrystie St',
#     'short_name': '5523.02',
#     'lat': 40.72229346,
#     'lon': -73.99147535,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 35,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=265',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '267',
#     'external_id': '66db473c-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Broadway & W 36 St',
#     'short_name': '6441.01',
#     'lat': 40.75097711,
#     'lon': -73.98765428,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 78,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=267',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '268',
#     'external_id': '66db479e-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Howard St & Centre St',
#     'short_name': '5422.04',
#     'lat': 40.71910537,
#     'lon': -73.99973337,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 27,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=268',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '270',
#     'external_id': '66db5c14-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Adelphi St & Myrtle Ave',
#     'short_name': '4620.02',
#     'lat': 40.69308257,
#     'lon': -73.97178913,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 23,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=270',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '274',
#     'external_id': '66db5d28-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Lafayette Ave & Fort Greene Pl',
#     'short_name': '4395.04',
#     'lat': 40.68691865,
#     'lon': -73.976682,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 31,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=274',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '275',
#     'external_id': '66db5d92-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Washington Ave & Greene Ave',
#     'short_name': '4419.03',
#     'lat': 40.68650065,
#     'lon': -73.96563307,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 19,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=275',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '276',
#     'external_id': '66db5dfb-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Duane St & Greenwich St',
#     'short_name': '5400.08',
#     'lat': 40.71748752,
#     'lon': -74.0104554,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 25,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=276',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '278',
#     'external_id': '66db5e6a-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Concord St & Bridge St',
#     'short_name': '4781.03',
#     'lat': 40.69766564,
#     'lon': -73.98476437,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 19,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=278',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '280',
#     'external_id': '66db5f40-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'E 10 St & 5 Ave',
#     'short_name': '5872.08',
#     'lat': 40.73331967,
#     'lon': -73.99510132,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 59,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=280',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '281',
#     'external_id': '66db5fae-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Grand Army Plaza & Central Park S',
#     'short_name': '6839.10',
#     'lat': 40.7643971,
#     'lon': -73.97371465,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 66,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=281',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '282',
#     'external_id': '66db6299-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Kent Ave & S 11 St',
#     'short_name': '5062.01',
#     'lat': 40.707644944175705,
#     'lon': -73.96841526031494,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 27,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=282',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '284',
#     'external_id': '66db631c-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Greenwich Ave & 8 Ave',
#     'short_name': '6072.06',
#     'lat': 40.7390169121,
#     'lon': -74.0026376103,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 43,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=284',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '285',
#     'external_id': '66db6387-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Broadway & E 14 St',
#     'short_name': '5905.12',
#     'lat': 40.73454567,
#     'lon': -73.99074142,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 53,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=285',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': True,
#     'has_kiosk': True},
#    {'station_id': '289',
#     'external_id': '66db63f4-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Monroe St & Classon Ave',
#     'short_name': '4336.01',
#     'lat': 40.6845683,
#     'lon': -73.95881081,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 19,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=289',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '291',
#     'external_id': '66db64d1-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Madison St & Montgomery St',
#     'short_name': '5262.09',
#     'lat': 40.713126,
#     'lon': -73.984844,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 20,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=291',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '293',
#     'external_id': '66db65aa-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Lafayette St & E 8 St',
#     'short_name': '5788.13',
#     'lat': 40.73020660529954,
#     'lon': -73.99102628231049,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 55,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=293',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '295',
#     'external_id': '66db6889-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Pike St & E Broadway',
#     'short_name': '5270.05',
#     'lat': 40.71406667,
#     'lon': -73.99293911,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 24,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=295',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '297',
#     'external_id': '66db6963-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'E 15 St & 3 Ave',
#     'short_name': '5863.07',
#     'lat': 40.734232,
#     'lon': -73.986923,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 27,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=297',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '298',
#     'external_id': '66db69d0-0aca-11e7-82f6-3863bb44ef7c',
#     'name': '3 Ave & Schermerhorn St',
#     'short_name': '4437.01',
#     'lat': 40.68683208,
#     'lon': -73.9796772,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 35,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=298',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '301',
#     'external_id': '66db6aae-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'E 2 St & Avenue B',
#     'short_name': '5515.02',
#     'lat': 40.72217444,
#     'lon': -73.98368779,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 58,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=301',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '302',
#     'external_id': '66db6cd4-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Avenue D & E 3 St',
#     'short_name': '5436.09',
#     'lat': 40.72082834,
#     'lon': -73.97793172,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 23,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=302',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '303',
#     'external_id': '66db6d40-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Mercer St & Spring St',
#     'short_name': '5532.01',
#     'lat': 40.72362738,
#     'lon': -73.99949601,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 67,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=303',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '304',
#     'external_id': '66db6da2-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Broadway & Battery Pl',
#     'short_name': '4962.01',
#     'lat': 40.70463334,
#     'lon': -74.01361706,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 33,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=304',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': True,
#     'has_kiosk': True},
#    {'station_id': '305',
#     'external_id': '66db6e49-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'E 58 St & 3 Ave',
#     'short_name': '6762.02',
#     'lat': 40.76095756,
#     'lon': -73.96724467,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 33,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=305',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '307',
#     'external_id': '66db6f2e-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Canal St & Rutgers St',
#     'short_name': '5303.08',
#     'lat': 40.71427487,
#     'lon': -73.98990025,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 30,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=307',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '308',
#     'external_id': '66db7152-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'St James Pl & Oliver St',
#     'short_name': '5238.05',
#     'lat': 40.71307916,
#     'lon': -73.99851193,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 27,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=308',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '309',
#     'external_id': '66db71be-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Murray St & West St',
#     'short_name': '5329.06',
#     'lat': 40.7149787,
#     'lon': -74.013012,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 41,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=309',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '310',
#     'external_id': '66db7221-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'State St & Smith St',
#     'short_name': '4565.06',
#     'lat': 40.68926942,
#     'lon': -73.98912867,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 36,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=310',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '311',
#     'external_id': '66db728c-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Norfolk St & Broome St',
#     'short_name': '5374.01',
#     'lat': 40.7172274,
#     'lon': -73.98802084,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 31,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=311',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '312',
#     'external_id': '66db72f1-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Allen St & Stanton St',
#     'short_name': '5484.09',
#     'lat': 40.722055,
#     'lon': -73.989111,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 31,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=312',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '313',
#     'external_id': '66db74a5-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Washington Ave & Park Ave',
#     'short_name': '4724.03',
#     'lat': 40.69610226,
#     'lon': -73.96751037,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 23,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=313',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '315',
#     'external_id': '66db75cc-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'South St & Gouverneur Ln',
#     'short_name': '4953.04',
#     'lat': 40.70355377,
#     'lon': -74.00670227,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 29,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=315',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': True,
#     'has_kiosk': True},
#    {'station_id': '316',
#     'external_id': '66db7637-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Fulton St & William St',
#     'short_name': '5137.11',
#     'lat': 40.70955958,
#     'lon': -74.00653609,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 43,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=316',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '317',
#     'external_id': '66db76a1-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'E 6 St & Avenue B',
#     'short_name': '5584.04',
#     'lat': 40.72453734,
#     'lon': -73.98185424,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 54,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=317',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '319',
#     'external_id': '66db79a3-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Fulton St & Broadway',
#     'short_name': '5175.08',
#     'lat': 40.711066,
#     'lon': -74.009447,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 33,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=319',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '320',
#     'external_id': '66db7a0d-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Leonard St & Church St',
#     'short_name': '5359.11',
#     'lat': 40.717571,
#     'lon': -74.005549,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 39,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=320',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '321',
#     'external_id': '66db7a71-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Cadman Plaza E & Red Cross Pl',
#     'short_name': '4821.06',
#     'lat': 40.69991755,
#     'lon': -73.98971773,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 27,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=321',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': True,
#     'has_kiosk': True},
#    {'station_id': '323',
#     'external_id': '66db88f5-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Lawrence St & Willoughby St',
#     'short_name': '4596.09',
#     'lat': 40.69236178,
#     'lon': -73.98631746,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 39,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=323',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '324',
#     'external_id': '66db89a3-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'DeKalb Ave & Hudson Ave',
#     'short_name': '4513.06',
#     'lat': 40.689888,
#     'lon': -73.981013,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 51,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=324',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '325',
#     'external_id': '66db8c10-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'E 19 St & 3 Ave',
#     'short_name': '5938.01',
#     'lat': 40.73624527,
#     'lon': -73.98473765,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 35,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=325',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '326',
#     'external_id': '66db8ca4-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'E 11 St & 1 Ave',
#     'short_name': '5746.14',
#     'lat': 40.72953837,
#     'lon': -73.98426726,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 41,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=326',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '327',
#     'external_id': '66db8d89-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Vesey Pl & River Terrace',
#     'short_name': '5297.02',
#     'lat': 40.7153379,
#     'lon': -74.01658354,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 39,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=327',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': True,
#     'has_kiosk': True},
#    {'station_id': '328',
#     'external_id': '66db8fde-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Watts St & Greenwich St',
#     'short_name': '5578.02',
#     'lat': 40.72405549,
#     'lon': -74.00965965,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 23,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=328',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '330',
#     'external_id': '66db90f1-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Reade St & Broadway',
#     'short_name': '5247.10',
#     'lat': 40.71450451,
#     'lon': -74.00562789,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 39,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=330',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '331',
#     'external_id': '66db930d-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Pike St & Monroe St',
#     'short_name': '5159.04',
#     'lat': 40.71173107,
#     'lon': -73.99193043,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 27,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=331',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '332',
#     'external_id': '66db93a1-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Cherry St',
#     'short_name': '5181.04',
#     'lat': 40.71219906,
#     'lon': -73.97948148,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 36,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=332',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '334',
#     'external_id': '66db95e5-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'W 20 St & 7 Ave',
#     'short_name': '6182.02',
#     'lat': 40.74238787,
#     'lon': -73.99726235,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 31,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=334',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '335',
#     'external_id': '66db9675-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Washington Pl & Broadway',
#     'short_name': '5755.01',
#     'lat': 40.72903917,
#     'lon': -73.99404649,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 27,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=335',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '336',
#     'external_id': '66db9845-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Sullivan St & Washington Sq',
#     'short_name': '5721.01',
#     'lat': 40.73047747,
#     'lon': -73.99906065,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 36,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=336',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '337',
#     'external_id': '66db9925-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Old Slip & Front St',
#     'short_name': '4993.12',
#     'lat': 40.7037992,
#     'lon': -74.00838676,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 37,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=337',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '339',
#     'external_id': '66db9c2e-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Avenue D & E 12 St',
#     'short_name': '5575.08',
#     'lat': 40.72580614,
#     'lon': -73.97422494,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
# ...
#     'external_id': 'a6a132f9-89bf-42a4-afe6-1ca449b7f570',
#     'name': 'Cypress Ave & George St',
#     'short_name': '4765.07',
#     'lat': 40.69812,
#     'lon': -73.90271,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 19,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3878',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3879',
#     'external_id': '679dcf08-d88c-4d1b-b81d-fe9f4aabbff7',
#     'name': 'Broadway & Madison St',
#     'short_name': '4483.10',
#     'lat': 40.68822,
#     'lon': -73.91966,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 25,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3879',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3880',
#     'external_id': 'ee1ba75f-baf5-4852-929c-8b7ad310f55a',
#     'name': 'Willoughby Ave & Onderdonk Ave',
#     'short_name': '5115.05',
#     'lat': 40.7098,
#     'lon': -73.91727,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 27,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3880',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3881',
#     'external_id': 'eab2749b-2f79-4797-a0a6-0579b27e6929',
#     'name': '12 Ave & W 125 St',
#     'short_name': '7886.02',
#     'lat': 40.818299,
#     'lon': -73.960405,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 39,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3881',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3882',
#     'external_id': '141ba25c-f4ea-4cec-ae7e-022401e23087',
#     'name': 'Norman St & Wyckoff Ave',
#     'short_name': '4654.01',
#     'lat': 40.69517,
#     'lon': -73.90311,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 15,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3882',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3883',
#     'external_id': 'a3e2b360-f050-48ea-b8c8-57d897b8f7fc',
#     'name': 'Harman St & Seneca Ave',
#     'short_name': '5002.09',
#     'lat': 40.70577,
#     'lon': -73.91292,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 19,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3883',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3884',
#     'external_id': 'a7c09fde-76e8-4a56-b61d-8ca940432efd',
#     'name': 'Centre St & Seneca Ave',
#     'short_name': '4837.03',
#     'lat': 40.69969,
#     'lon': -73.9022,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 23,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3884',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3885',
#     'external_id': '1057229c-f8f8-4014-80cd-f40421c61cf0',
#     'name': 'Onderdonk Ave & Gates Ave',
#     'short_name': '4994.10',
#     'lat': 40.70413,
#     'lon': -73.90737,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 19,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3885',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3886',
#     'external_id': '8f3a6711-fd05-4ce1-acf8-9d72b4a1bf97',
#     'name': 'Menahan St & Onderdonk Ave',
#     'short_name': '5034.03',
#     'lat': 40.70553,
#     'lon': -73.9096,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 20,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3886',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3887',
#     'external_id': 'd89dc10f-9be3-45a5-9c3c-06c04c963436',
#     'name': 'Flushing Ave & Woodward Ave',
#     'short_name': '5225.02',
#     'lat': 40.71246,
#     'lon': -73.91873,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 21,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3887',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3888',
#     'external_id': '55a4dc76-d839-4e06-9bf4-2f343391343c',
#     'name': 'Woodward Ave & Harman St',
#     'short_name': '5074.08',
#     'lat': 40.70793,
#     'lon': -73.91092,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 19,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3888',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3890',
#     'external_id': 'ad57266c-34da-43da-8b48-2ba856002fbf',
#     'name': 'Grove St & Broadway',
#     'short_name': '4526.01',
#     'lat': 40.69047,
#     'lon': -73.923511,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 31,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3890',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3891',
#     'external_id': 'b35ba3c0-d3e8-4b1a-b63b-73a7bb518c9e',
#     'name': 'Irving Ave & Palmetto St',
#     'short_name': '4775.01',
#     'lat': 40.698,
#     'lon': -73.9127,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 20,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3891',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3892',
#     'external_id': 'ad41e353-033e-484f-8d76-78014e11e9d7',
#     'name': '38 Ave & 29 St',
#     'short_name': '6538.11',
#     'lat': 40.75473,
#     'lon': -73.93367,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 19,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3892',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3893',
#     'external_id': '59e3766c-0629-4ff1-a1d9-bc0514a55487',
#     'name': 'Rockaway Ave & Bainbridge St',
#     'short_name': '4285.09',
#     'lat': 40.68319988172761,
#     'lon': -73.91166642308235,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 25,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3893',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3895',
#     'external_id': '87091002-cc25-452a-b5d9-f8d0c3fce422',
#     'name': 'Cypress Ave & Palmetto St',
#     'short_name': '4921.04',
#     'lat': 40.701573408737914,
#     'lon': -73.90876293182373,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 25,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3895',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3896',
#     'external_id': '26cae473-0e59-4af7-bad5-bb6fec85c8bc',
#     'name': 'Madison St & Seneca Ave',
#     'short_name': '4880.11',
#     'lat': 40.70183,
#     'lon': -73.90625,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 22,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3896',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3897',
#     'external_id': 'be8e6f1c-e8b5-40bd-896d-423052ba3bbc',
#     'name': 'Onderdonk Ave & Dekalb Ave',
#     'short_name': '5115.01',
#     'lat': 40.70863,
#     'lon': -73.91497,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 17,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3897',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3898',
#     'external_id': '199ea9dd-8f7e-4e05-a730-55edaacd8787',
#     'name': 'E 63 St & 3 Ave',
#     'short_name': '6830.02',
#     'lat': 40.763954,
#     'lon': -73.9646,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 57,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3898',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3899',
#     'external_id': 'bd30f2a1-38ec-474d-9e36-07f688e87427',
#     'name': 'Manhattan Av & Leonard St',
#     'short_name': '5442.09',
#     'lat': 40.72084,
#     'lon': -73.94844,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 18,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3899',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3900',
#     'external_id': '344064f8-e82f-40fb-b235-aff506b77ae5',
#     'name': 'Morgan Ave & Lombardy St',
#     'short_name': '5503.01',
#     'lat': 40.72226,
#     'lon': -73.93889,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 30,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3900',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3901',
#     'external_id': '837b7db3-55c6-4595-a497-834972631752',
#     'name': 'Stanhope St & Fairview Ave',
#     'short_name': '5146.03',
#     'lat': 40.70998,
#     'lon': -73.91116,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 17,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3901',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3902',
#     'external_id': '1abd4668-ed6b-4930-8177-17239ae75a9e',
#     'name': 'Fairview Ave & Linden St',
#     'short_name': '5066.03',
#     'lat': 40.70694,
#     'lon': -73.90632,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 19,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3902',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3903',
#     'external_id': '88ee054e-bdeb-4305-8f3b-76eb964f2c84',
#     'name': 'Jefferson Ave & Evergreen Ave',
#     'short_name': '4517.03',
#     'lat': 40.68989,
#     'lon': -73.91458,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 17,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3903',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3905',
#     'external_id': '0f45bcf6-7028-4584-a51e-4129847dbebc',
#     'name': '4 Ave & E 12 St',
#     'short_name': '5788.15',
#     'lat': 40.732647,
#     'lon': -73.99011,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 27,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3905',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3907',
#     'external_id': '75352ab4-8a31-4926-8b59-048a9e506452',
#     'name': 'Central Ave & Melrose St',
#     'short_name': '4832.07',
#     'lat': 40.70112,
#     'lon': -73.93039,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 17,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3907',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3909',
#     'external_id': '16836c76-c412-4ec3-bac8-3c6a5a3d9745',
#     'name': 'Madison St & Woodward Ave',
#     'short_name': '4954.07',
#     'lat': 40.70408,
#     'lon': -73.90408,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 20,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3909',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3910',
#     'external_id': '30985a9c-afe4-4b98-a72c-2c72bb35603e',
#     'name': 'Greene Ave & Grandview Ave',
#     'short_name': '5106.04',
#     'lat': 40.709697,
#     'lon': -73.907856,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 17,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3910',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3911',
#     'external_id': '8d553914-6de8-428c-b620-d3c5d66bbb45',
#     'name': 'Wyckoff St & Nevins St',
#     'short_name': '4290.08',
#     'lat': 40.683426,
#     'lon': -73.984275,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 22,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3911',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3913',
#     'external_id': '8dfff4bd-0f3c-43af-bc55-a63850f66c6b',
#     'name': 'Sands St Gate',
#     'short_name': '4812.04',
#     'lat': 40.699569,
#     'lon': -73.979827,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 19,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3913',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3914',
#     'external_id': '8bab3ee9-1302-46a0-b755-f21a2ff4e7ba',
#     'name': 'West End Ave & W 78 St',
#     'short_name': '7340.07',
#     'lat': 40.783786,
#     'lon': -73.981687,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 39,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3914',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3916',
#     'external_id': '8deeaea2-aa12-4925-9ee0-5f9bd0cde7e6',
#     'name': 'Pearl St & Peck Slip',
#     'short_name': '5096.11',
#     'lat': 40.708485,
#     'lon': -74.002751,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 45,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3916',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': True,
#     'has_kiosk': True},
#    {'station_id': '3917',
#     'external_id': '582cd775-0178-47f5-b707-6d5869f077ba',
#     'name': 'Willoughby St & Ashland Pl',
#     'short_name': '4587.02',
#     'lat': 40.69178,
#     'lon': -73.97877,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 31,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3917',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3918',
#     'external_id': '2d086235-2516-4aa0-a6c1-0ba3b03b6ec6',
#     'name': 'Avenue D & E 8 St',
#     'short_name': '5575.12',
#     'lat': 40.72387,
#     'lon': -73.975767,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 30,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3918',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True}]}}

# %%
# station_info_data is a dictionary (which contains several sub-dictionaries).
# Get a list of keys within the station_info_data['data'] dictionary:
station_info_data['data'].keys()
# Out:
# dict_keys(['stations'])

# %%
# How many stations are there?
len(station_info_data['data']['stations'])
# Out:
# 935

# %%
# Convert the JSON data into a Pandas dataframe:
station_info_df = pd.DataFrame(station_info_data['data']['stations'])
station_info_df.head()
# Out:
#   station_id                           external_id  \
# 0         72  66db237e-0aca-11e7-82f6-3863bb44ef7c
# 1         79  66db269c-0aca-11e7-82f6-3863bb44ef7c
# 2         82  66db277a-0aca-11e7-82f6-3863bb44ef7c
# 3         83  66db281e-0aca-11e7-82f6-3863bb44ef7c
# 4        116  66db28b5-0aca-11e7-82f6-3863bb44ef7c
#
#                             name short_name        lat        lon  region_id  \
# 0               W 52 St & 11 Ave    6926.01  40.767272 -73.993929         71
# 1       Franklin St & W Broadway    5430.08  40.719116 -74.006667         71
# 2         St James Pl & Pearl St    5167.06  40.711174 -74.000165         71
# 3  Atlantic Ave & Fort Greene Pl    4354.07  40.683826 -73.976323         71
# 4                W 17 St & 8 Ave    6148.02  40.741776 -74.001497         71
#
#       rental_methods  capacity  \
# 0  [CREDITCARD, KEY]        55
# 1  [CREDITCARD, KEY]        33
# 2  [CREDITCARD, KEY]        27
# 3  [CREDITCARD, KEY]        62
# 4  [CREDITCARD, KEY]        50
#
#                                           rental_url  \
# 0  http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...
# 1  http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...
# 2  http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...
# 3  http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...
# 4  http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...
#
#    electric_bike_surcharge_waiver  eightd_has_key_dispenser  has_kiosk
# 0                           False                     False       True
# 1                           False                     False       True
# 2                           False                     False       True
# 3                           False                     False       True
# 4                           False                     False       True

# %%
station_info_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 935 entries, 0 to 934
# Data columns (total 13 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   station_id                      935 non-null    object
#  1   external_id                     935 non-null    object
#  2   name                            935 non-null    object
#  3   short_name                      935 non-null    object
#  4   lat                             935 non-null    float64
#  5   lon                             935 non-null    float64
#  6   region_id                       935 non-null    int64
#  7   rental_methods                  935 non-null    object
#  8   capacity                        935 non-null    int64
#  9   rental_url                      935 non-null    object
#  10  electric_bike_surcharge_waiver  935 non-null    bool
#  11  eightd_has_key_dispenser        935 non-null    bool
#  12  has_kiosk                       935 non-null    bool
# dtypes: bool(3), float64(2), int64(2), object(6)
# memory usage: 75.9+ KB

# %%
bike_trips_df = pd.read_csv('2013-09 - Citi Bike trip data.csv')

# %%
bike_trips_df.tail()
# Out:
#          tripduration            starttime             stoptime  \
# 1034354            93  2013-09-30 23:59:16  2013-10-01 00:00:49
# 1034355           363  2013-09-30 23:59:21  2013-10-01 00:05:24
# 1034356           562  2013-09-30 23:59:30  2013-10-01 00:08:52
# 1034357          1237  2013-09-30 23:59:40  2013-10-01 00:20:17
# 1034358          1292  2013-09-30 23:59:53  2013-10-01 00:21:25
#
#          start station id     start station name  start station latitude  \
# 1034354               360   William St & Pine St               40.707179
# 1034355              2003        1 Ave & E 18 St               40.734161
# 1034356               293  Lafayette St & E 8 St               40.730287
# 1034357               478       11 Ave & W 41 St               40.760301
# 1034358               363         West Thames St               40.708347
#
#          start station longitude  end station id          end station name  \
# 1034354               -74.008873             195     Liberty St & Broadway
# 1034355               -73.980243             459          W 20 St & 11 Ave
# 1034356               -73.990765             463           9 Ave & W 16 St
# 1034357               -73.998842             318  E 43 St & Vanderbilt Ave
# 1034358               -74.017134             363            West Thames St
#
#          end station latitude  end station longitude  bikeid    usertype  \
# 1034354             40.709056             -74.010434   20594  Subscriber
# 1034355             40.746745             -74.007756   15213    Customer
# 1034356             40.742065             -74.004432   17938  Subscriber
# 1034357             40.753202             -73.977987   15931    Customer
# 1034358             40.708347             -74.017134   14826    Customer
#
#         birth year  gender
# 1034354       1989       1
# 1034355         \N       0
# 1034356       1967       1
# 1034357         \N       0
# 1034358         \N       0

# %%
# bike_trips_df.columns

# Using `list()` formats things a little better:
list(bike_trips_df.columns)
# Out:
# ['tripduration',
#  'starttime',
#  'stoptime',
#  'start station id',
#  'start station name',
#  'start station latitude',
#  'start station longitude',
#  'end station id',
#  'end station name',
#  'end station latitude',
#  'end station longitude',
#  'bikeid',
#  'usertype',
#  'birth year',
#  'gender']

# %%
nodes = vrv.initDataframe('nodes')

# %%
# Here are the columns we'll need to populate:
list(nodes.columns)
# Out:
# ['id',
#  'lat',
#  'lon',
#  'altMeters',
#  'nodeName',
#  'nodeType',
#  'leafletIconPrefix',
#  'leafletIconType',
#  'leafletColor',
#  'leafletIconText',
#  'cesiumIconType',
#  'cesiumColor',
#  'cesiumIconText']

# %%
# Here are the columns from our "Station Info":
list(station_info_df.columns)
# Out:
# ['station_id',
#  'external_id',
#  'name',
#  'short_name',
#  'lat',
#  'lon',
#  'region_id',
#  'rental_methods',
#  'capacity',
#  'rental_url',
#  'electric_bike_surcharge_waiver',
#  'eightd_has_key_dispenser',
#  'has_kiosk']

# %%
# An example to show the syntax for displaying 2 particular columns from a df:
station_info_df[['lat', 'lon']].head()
# Out:
#          lat        lon
# 0  40.767272 -73.993929
# 1  40.719116 -74.006667
# 2  40.711174 -74.000165
# 3  40.683826 -73.976323
# 4  40.741776 -74.001497

# %%
# Let's go ahead and re-initialize an empty dataframe within this cell:
nodes = vrv.initDataframe('nodes')

# Now, copy the relevant columns from our Station Info dataframe:
# NOTE: We were getting some size mis-match errors until we copied 
#       just a single column first.  
nodes['id'] = station_info_df['station_id'].values
nodes[['id', 'lat', 'lon', 'nodeName']] = station_info_df[['station_id', 'lat', 'lon', 'name']].values
nodes[['leafletIconText', 'cesiumIconText']] = station_info_df[['name', 'station_id']].values
nodes[['leafletColor', 'cesiumColor']] = station_status_df[['lcolor', 'ccolor']].values

# Finally, we'll fill in the rest of our nodes dataframe with some hard-coded/constant values:
nodes.loc[:,'altMeters'] = 0
nodes.loc[:,['nodeType', 'leafletIconPrefix', 'leafletIconType']] = [
             'CitiBikeStation',  'fa',                'bicycle']
nodes.loc[:,['cesiumIconType']] = ['pin']

# %%
nodes.head()
# Out:
#     id      lat      lon  altMeters                       nodeName  \
# 0   72  40.7673 -73.9939          0               W 52 St & 11 Ave
# 1   79  40.7191 -74.0067          0       Franklin St & W Broadway
# 2   82  40.7112 -74.0002          0         St James Pl & Pearl St
# 3   83  40.6838 -73.9763          0  Atlantic Ave & Fort Greene Pl
# 4  116  40.7418 -74.0015          0                W 17 St & 8 Ave
#
#           nodeType leafletIconPrefix leafletIconType leafletColor  \
# 0  CitiBikeStation                fa         bicycle        green
# 1  CitiBikeStation                fa         bicycle        green
# 2  CitiBikeStation                fa         bicycle        green
# 3  CitiBikeStation                fa         bicycle        green
# 4  CitiBikeStation                fa         bicycle        green
#
#                  leafletIconText cesiumIconType         cesiumColor  \
# 0               W 52 St & 11 Ave            pin  Cesium.Color.GREEN
# 1       Franklin St & W Broadway            pin  Cesium.Color.GREEN
# 2         St James Pl & Pearl St            pin  Cesium.Color.GREEN
# 3  Atlantic Ave & Fort Greene Pl            pin  Cesium.Color.GREEN
# 4                W 17 St & 8 Ave            pin  Cesium.Color.GREEN
#
#   cesiumIconText
# 0             72
# 1             79
# 2             82
# 3             83
# 4            116

# %%
nodes.tail()
# Out:
#        id      lat      lon  altMeters                    nodeName  \
# 930  3913  40.6996 -73.9798          0               Sands St Gate
# 931  3914  40.7838 -73.9817          0      West End Ave & W 78 St
# 932  3916  40.7085 -74.0028          0        Pearl St & Peck Slip
# 933  3917  40.6918 -73.9788          0  Willoughby St & Ashland Pl
# 934  3918  40.7239 -73.9758          0           Avenue D & E 8 St
#
#             nodeType leafletIconPrefix leafletIconType leafletColor  \
# 930  CitiBikeStation                fa         bicycle        green
# 931  CitiBikeStation                fa         bicycle        green
# 932  CitiBikeStation                fa         bicycle        green
# 933  CitiBikeStation                fa         bicycle        green
# 934  CitiBikeStation                fa         bicycle        green
#
#                 leafletIconText cesiumIconType         cesiumColor  \
# 930               Sands St Gate            pin  Cesium.Color.GREEN
# 931      West End Ave & W 78 St            pin  Cesium.Color.GREEN
# 932        Pearl St & Peck Slip            pin  Cesium.Color.GREEN
# 933  Willoughby St & Ashland Pl            pin  Cesium.Color.GREEN
# 934           Avenue D & E 8 St            pin  Cesium.Color.GREEN
#
#     cesiumIconText
# 930           3913
# 931           3914
# 932           3916
# 933           3917
# 934           3918

# %%
# Show all of the nodes on a Leaflet map:
vrv.createLeaflet(nodes=nodes)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# NOTE:  VeRoViz also has an "arcs" dataframe,
#        but it doesn't have time-related columns.
arcs = vrv.initDataframe('arcs')
list(arcs.columns)

# We won't use the "arcs" dataframe
# Out:
# ['odID',
#  'objectID',
#  'startLat',
#  'startLon',
#  'endLat',
#  'endLon',
#  'leafletColor',
#  'leafletWeight',
#  'leafletStyle',
#  'leafletOpacity',
#  'useArrows',
#  'cesiumColor',
#  'cesiumWeight',
#  'cesiumStyle',
#  'cesiumOpacity']

# %%
# FIXME

# Some (most?) of our bikes are being re-positioned by the CitiBike staff.
# We'll want to identify when this happens.

# One way to identify that a re-positioning has occurred is if 
# The start location for the next arc of a given bike does not 
# match the end location of the previous arc for this bike.

# We might also want to know when these activities occur.
# Is it only at night?  Do we have enough data to figure this out?

# Option1: Use "for" loop
# Option2: Do not use "for" loop
# Which option is faster?
#   timeit() - part of ipython
#   import timeit
#   current time - previous time
# Draw on a separate Leaflet map and a (separate?) Cesium movie
# The repositioning of bikes
# Color the arcs differently? end time of previous station to start time of next station

# bike does not show up if it is static
# Use vrv.addStaticAssignment() to display stationary bikes,
#   Can we append to end of assignment dataframe
#

# %%
# for a particular bike

from datetime import datetime
bike_trips_df_14529 = pd.DataFrame(bike_trips_df.loc[bike_trips_df['bikeid'] == 14529]).reset_index(drop = True)
#bike_trips_df_14529['enddate'] = pd.to_datetime(bike_trips_df_14529['stoptime'], utc=False).values.astype('M8[D]')
bike_trips_df_14529['repos'] = 'no'
bike_trips_df_14529['repostime'] = ''
for i in range(len(bike_trips_df_14529)):
    if i+1 <= len(bike_trips_df_14529)-1:
        if bike_trips_df_14529.loc[i,'end station id'] != bike_trips_df_14529.loc[i+1,'start station id']:
            bike_trips_df_14529.loc[i+1,'repos'] = 'yes'
            bike_trips_df_14529.loc[i+1,'repostime'] = datetime.strptime(bike_trips_df_14529.loc[i+1,'stoptime'],'%Y-%m-%d %H:%M:%S').time()
    else:
        pass

# %%
bike_trips_df_14529.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           382  2013-09-02 13:18:19  2013-09-02 13:24:41               323
# 1           142  2013-09-02 13:28:58  2013-09-02 13:31:20               403
# 2          1572  2013-09-02 15:55:28  2013-09-02 16:21:40               236
# 3           383  2013-09-02 20:20:54  2013-09-02 20:27:17               368
# 4           342  2013-09-02 21:14:57  2013-09-02 21:20:39               168
#
#             start station name  start station latitude  \
# 0  Lawrence St & Willoughby St               40.692362
# 1               E 2 St & 2 Ave               40.725029
# 2          St Marks Pl & 2 Ave               40.728419
# 3           Carmine St & 6 Ave               40.730386
# 4              W 18 St & 6 Ave               40.739713
#
#    start station longitude  end station id          end station name  \
# 0               -73.986317             403            E 2 St & 2 Ave
# 1               -73.990697             265  Stanton St & Chrystie St
# 2               -73.987140             195     Liberty St & Broadway
# 3               -74.002150             168           W 18 St & 6 Ave
# 4               -73.994564             442           W 27 St & 7 Ave
#
#    end station latitude  end station longitude  bikeid    usertype birth year  \
# 0             40.725029             -73.990697   14529    Customer         \N
# 1             40.722293             -73.991475   14529  Subscriber       1987
# 2             40.709056             -74.010434   14529  Subscriber       1975
# 3             40.739713             -73.994564   14529  Subscriber       1985
# 4             40.746647             -73.993915   14529  Subscriber       1988
#
#    gender repos repostime
# 0       0    no
# 1       1    no
# 2       2   yes  16:21:40
# 3       1   yes  20:27:17
# 4       1    no

# %%
# Initialize an empty "assignments" dataframe:
assignments = vrv.initDataframe('assignments')
assignments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 22 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   odID            0 non-null      object
#  1   objectID        0 non-null      object
#  2   modelFile       0 non-null      object
#  3   modelScale      0 non-null      object
#  4   modelMinPxSize  0 non-null      object
#  5   startTimeSec    0 non-null      object
#  6   startLat        0 non-null      object
#  7   startLon        0 non-null      object
#  8   startAltMeters  0 non-null      object
#  9   endTimeSec      0 non-null      object
#  10  endLat          0 non-null      object
#  11  endLon          0 non-null      object
#  12  endAltMeters    0 non-null      object
#  13  leafletColor    0 non-null      object
#  14  leafletWeight   0 non-null      object
#  15  leafletStyle    0 non-null      object
#  16  leafletOpacity  0 non-null      object
#  17  useArrows       0 non-null      object
#  18  cesiumColor     0 non-null      object
#  19  cesiumWeight    0 non-null      object
#  20  cesiumStyle     0 non-null      object
#  21  cesiumOpacity   0 non-null      object
# dtypes: object(22)
# memory usage: 0.0+ bytes

# %%
# What is the first start time in our bike_trips_df?
min(bike_trips_df['starttime'])
# Out:
# '2013-09-01 00:00:02'

# %%
# Add a new column to bike_trips_df...

# This next command will produce a "timestamp" (days HH:MM:SS.ms) 
# showing the time since the first observed `starttime`:
bike_trips_df['timeAfterStart'] = pd.to_datetime(bike_trips_df['starttime']) - \
                                  pd.to_datetime(min(bike_trips_df['starttime']))

# Now, convert this to a decimal number of seconds:
bike_trips_df['timeAfterStart'] = bike_trips_df['timeAfterStart'].dt.total_seconds().astype(int)

bike_trips_df['timeAfterStart'].head()
# Out:
# 0     0
# 1     7
# 2    14
# 3    16
# 4    18
# Name: timeAfterStart, dtype: int32

# %%
# Just for fun, here's the time differences between start/stop times:
pd.to_datetime(bike_trips_df['stoptime']) - pd.to_datetime(bike_trips_df['starttime'])
# Out:
# 0         00:16:50
# 1         00:24:03
# 2         00:23:07
# 3         00:06:45
# 4         00:04:30
#             ...
# 1034354   00:01:33
# 1034355   00:06:03
# 1034356   00:09:22
# 1034357   00:20:37
# 1034358   00:21:32
# Length: 1034359, dtype: timedelta64[ns]

# %%
# odID is an abbreviation for “origin/ destination identifier”. 
# It is a group identifier. Arc segments which are part of the same origin/destination share the same odID.

# In one cell, we'll create our assignments dataframe.

# Make sure we're starting with an empty dataframe:
assignments = vrv.initDataframe('assignments')

# Copy over the static values.
# We'll start by copying a single column, to avoid the size mis-match issue:
assignments['objectID'] = bike_trips_df['bikeid']
assignments[['startLat', 'startLon', 'endLat', 'endLon']] = bike_trips_df[['start station latitude', 
                                                                          'start station longitude',
                                                                          'end station latitude',
                                                                          'end station longitude']].values

# Copy our new calculated column:
assignments['startTimeSec'] = bike_trips_df['timeAfterStart'].values

# Use the calculated column and tripduration to get the end time (in seconds):
assignments['endTimeSec'] = (bike_trips_df['timeAfterStart'] + bike_trips_df['tripduration']).values

# Fill in the rest of our assignments df with some hard-coded values:
# (we'll probably want to revisit this later)
assignments.loc[:,['modelFile', 'modelScale', 'modelMinPxSize', 'startAltMeters', 'endAltMeters', 
                   'leafletColor', 'leafletWeight', 'leafletStyle', 'leafletOpacity', 'useArrows',
                   'cesiumColor', 'cesiumWeight', 'cesiumStyle', 'cesiumOpacity']] = \
                  ['veroviz/models/car_blue.gltf', 100, 45, 0, 0, 
                   'blue', 2, 'solid', 0.8, False, 
                   'Cesium.Color.BLUE', 2, 'solid', 0.7]

# Finally (for now), let's generate a unique odID value for each row.
# This will make sense only if we assume that each row corresponds to a specific
# O/D pair.  Conversely, if we have turn-by-turn arcs, we'll need to group
# multiple rows into the same O/D pair.  We'll tackle that case if/when 
# we encounter it.
assignments.loc[:,'odID'] = list(range(0, len(assignments)))

# %%
# Display what we've created:
assignments.head()
# Out:
#    odID  objectID                     modelFile  modelScale  modelMinPxSize  \
# 0     0     15014  veroviz/models/car_blue.gltf         100              45
# 1     1     19393  veroviz/models/car_blue.gltf         100              45
# 2     2     16160  veroviz/models/car_blue.gltf         100              45
# 3     3     14997  veroviz/models/car_blue.gltf         100              45
# 4     4     19609  veroviz/models/car_blue.gltf         100              45
#
#    startTimeSec   startLat   startLon  startAltMeters  endTimeSec  ...  \
# 0             0  40.735324 -73.998004               0        1010  ...
# 1             7  40.721816 -73.997203               0        1450  ...
# 2            14  40.763406 -73.977225               0        1401  ...
# 3            16  40.751551 -73.993934               0         421  ...
# 4            18  40.728419 -73.987140               0         288  ...
#
#    endAltMeters  leafletColor  leafletWeight leafletStyle  leafletOpacity  \
# 0             0          blue              2        solid             0.8
# 1             0          blue              2        solid             0.8
# 2             0          blue              2        solid             0.8
# 3             0          blue              2        solid             0.8
# 4             0          blue              2        solid             0.8
#
#   useArrows        cesiumColor  cesiumWeight cesiumStyle  cesiumOpacity
# 0     False  Cesium.Color.BLUE             2       solid            0.7
# 1     False  Cesium.Color.BLUE             2       solid            0.7
# 2     False  Cesium.Color.BLUE             2       solid            0.7
# 3     False  Cesium.Color.BLUE             2       solid            0.7
# 4     False  Cesium.Color.BLUE             2       solid            0.7
#
# [5 rows x 22 columns]

# %%
# Create a leaflet map

# I'll just choose the bike with the smallest ID number:
assignments[assignments['objectID'] == min(assignments['objectID'])]
# Out:
#           odID  objectID                     modelFile  modelScale  \
# 33345    33345     14529  veroviz/models/car_blue.gltf         100
# 33696    33696     14529  veroviz/models/car_blue.gltf         100
# 36193    36193     14529  veroviz/models/car_blue.gltf         100
# 43976    43976     14529  veroviz/models/car_blue.gltf         100
# 44906    44906     14529  veroviz/models/car_blue.gltf         100
# ...        ...       ...                           ...         ...
# 979401  979401     14529  veroviz/models/car_blue.gltf         100
# 981899  981899     14529  veroviz/models/car_blue.gltf         100
# 985594  985594     14529  veroviz/models/car_blue.gltf         100
# 987651  987651     14529  veroviz/models/car_blue.gltf         100
# 990449  990449     14529  veroviz/models/car_blue.gltf         100
#
#         modelMinPxSize  startTimeSec   startLat   startLon  startAltMeters  \
# 33345               45        134297  40.692362 -73.986317               0
# 33696               45        134936  40.725029 -73.990697               0
# 36193               45        143726  40.728419 -73.987140               0
# 43976               45        159652  40.730386 -74.002150               0
# 44906               45        162895  40.739713 -73.994564               0
# ...                ...           ...        ...        ...             ...
# 979401              45       2471545  40.683178 -73.965964               0
# 981899              45       2474695  40.693631 -73.962236               0
# 985594              45       2479190  40.687979 -73.978474               0
# 987651              45       2481642  40.680983 -73.950048               0
# 990449              45       2485189  40.685144 -73.953809               0
#
#         endTimeSec  ...  endAltMeters  leafletColor  leafletWeight  \
# 33345       134679  ...             0          blue              2
# 33696       135078  ...             0          blue              2
# 36193       145298  ...             0          blue              2
# 43976       160035  ...             0          blue              2
# 44906       163237  ...             0          blue              2
# ...            ...  ...           ...           ...            ...
# 979401     2472899  ...             0          blue              2
# 981899     2475276  ...             0          blue              2
# 985594     2480003  ...             0          blue              2
# 987651     2481874  ...             0          blue              2
# 990449     2486272  ...             0          blue              2
#
#        leafletStyle  leafletOpacity useArrows        cesiumColor  \
# 33345         solid             0.8     False  Cesium.Color.BLUE
# 33696         solid             0.8     False  Cesium.Color.BLUE
# 36193         solid             0.8     False  Cesium.Color.BLUE
# 43976         solid             0.8     False  Cesium.Color.BLUE
# 44906         solid             0.8     False  Cesium.Color.BLUE
# ...             ...             ...       ...                ...
# 979401        solid             0.8     False  Cesium.Color.BLUE
# 981899        solid             0.8     False  Cesium.Color.BLUE
# 985594        solid             0.8     False  Cesium.Color.BLUE
# 987651        solid             0.8     False  Cesium.Color.BLUE
# 990449        solid             0.8     False  Cesium.Color.BLUE
#
#         cesiumWeight cesiumStyle  cesiumOpacity
# 33345              2       solid            0.7
# 33696              2       solid            0.7
# 36193              2       solid            0.7
# 43976              2       solid            0.7
# 44906              2       solid            0.7
# ...              ...         ...            ...
# 979401             2       solid            0.7
# 981899             2       solid            0.7
# 985594             2       solid            0.7
# 987651             2       solid            0.7
# 990449             2       solid            0.7
#
# [152 rows x 22 columns]

# %%
# Show all of the arcs for this particular bike:
vrv.createLeaflet(arcs=assignments[assignments['objectID'] == 14529])
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Create a Cesium movie for one bike

# Use this command to get documentation on the `createCesium()` function:
vrv.createCesium?

# %%
# FIXME

# The Cesium movie is cluttered with all of our station markers.
# It would be better to only include the markers that are actually relevant 
# to our given bike.

# Fortunately, our bike trips df contains the station IDs.
# We just need to get a list of unique IDs, and then 
# pass to createCesium only the subset of nodes corresponding to these IDs.

# %%
# list of stations
Stations_14529 = list(set(list(bike_trips_df_14529['start station id'].unique()) + list(bike_trips_df_14529['end station id'].unique())))
station_info_df_14529 = station_info_df.loc[~station_info_df['station_id'].isin(Stations_14529)] 
station_status_df_14529 = station_status_df.loc[~station_status_df['station_id'].isin(Stations_14529)]

# %%
# Let's go ahead and re-initialize an empty dataframe within this cell:
nodes_14529 = vrv.initDataframe('nodes')

# Now, copy the relevant columns from our Station Info dataframe:
# NOTE: We were getting some size mis-match errors until we copied 
#       just a single column first.  
nodes_14529['id'] = station_info_df_14529['station_id'].values
nodes_14529[['id', 'lat', 'lon', 'nodeName']] = station_info_df_14529[['station_id', 'lat', 'lon', 'name']].values
nodes_14529[['leafletIconText', 'cesiumIconText']] = station_info_df_14529[['name', 'station_id']].values
nodes_14529[['leafletColor', 'cesiumColor']] = station_status_df_14529[['lcolor', 'ccolor']].values

# Finally, we'll fill in the rest of our nodes dataframe with some hard-coded/constant values:
nodes_14529.loc[:,'altMeters'] = 0
nodes_14529.loc[:,['nodeType', 'leafletIconPrefix', 'leafletIconType']] = [
             'CitiBikeStation',  'fa',                'bicycle']
nodes_14529.loc[:,['cesiumIconType']] = ['pin']

# %%
# Show all of the nodes on a Leaflet map:
vrv.createLeaflet(nodes=nodes_14529)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# startDate: Format is "YYYY-MM-DD"
startDate = pd.to_datetime(min(bike_trips_df['starttime'])).strftime('%Y-%m-%d')

# startTime: Format is "HH:MM:SS"
startTime = pd.to_datetime(min(bike_trips_df['starttime'])).strftime('%H:%M:%S')

vrv.createCesium(
    assignments = assignments[assignments['objectID'] == 14529],
    nodes       = nodes_14529,
    startDate   = startDate,
    startTime   = startTime,
    cesiumDir   = os.environ['CESIUMDIR'],
    problemDir  = 'IE_670/citibike_example_14529')
# Out:
# Message: File selector was written to C:/Users/obejo/Downloads/Cesium-1.66/IE_670/citibike_example_14529/;IE_670;citibike_example_14529.vrv ...
# Message: Configs were written to C:/Users/obejo/Downloads/Cesium-1.66/IE_670/citibike_example_14529/config.js ...
# Message: Nodes were written to C:/Users/obejo/Downloads/Cesium-1.66/IE_670/citibike_example_14529/displayNodes.js ...
# Message: Assignments (.js) were written to C:/Users/obejo/Downloads/Cesium-1.66/IE_670/citibike_example_14529/displayPaths.js ...
# Message: Assignments (.czml) were written to C:/Users/obejo/Downloads/Cesium-1.66/IE_670/citibike_example_14529/routes.czml ...

# %%
# startDate: Format is "YYYY-MM-DD"
startDate = pd.to_datetime(min(bike_trips_df['starttime'])).strftime('%Y-%m-%d')

# startTime: Format is "HH:MM:SS"
startTime = pd.to_datetime(min(bike_trips_df['starttime'])).strftime('%H:%M:%S')

vrv.createCesium(
    assignments = assignments[assignments['objectID'] == 14529],
    nodes       = nodes,
    startDate   = startDate,
    startTime   = startTime,
    cesiumDir   = os.environ['CESIUMDIR'],
    problemDir  = 'IE_670/citibike_example')
# Out:
# Message: File selector was written to C:/Users/obejo/Downloads/Cesium-1.66/IE_670/citibike_example/;IE_670;citibike_example.vrv ...
# Message: Configs were written to C:/Users/obejo/Downloads/Cesium-1.66/IE_670/citibike_example/config.js ...
# Message: Nodes were written to C:/Users/obejo/Downloads/Cesium-1.66/IE_670/citibike_example/displayNodes.js ...
# Message: Assignments (.js) were written to C:/Users/obejo/Downloads/Cesium-1.66/IE_670/citibike_example/displayPaths.js ...
# Message: Assignments (.czml) were written to C:/Users/obejo/Downloads/Cesium-1.66/IE_670/citibike_example/routes.czml ...

# %%
pd.to_datetime(bike_trips_df['starttime']).dt.date
# Out:
# 0          2013-09-01
# 1          2013-09-01
# 2          2013-09-01
# 3          2013-09-01
# 4          2013-09-01
#               ...
# 1034354    2013-09-30
# 1034355    2013-09-30
# 1034356    2013-09-30
# 1034357    2013-09-30
# 1034358    2013-09-30
# Name: starttime, Length: 1034359, dtype: object

# %%
pd.to_datetime(min(bike_trips_df['starttime'])).strftime('%Y-%m-%d')
# Out:
# '2013-09-01'

# %%
pd.to_datetime(min(bike_trips_df['starttime'])).strftime('%H:%M:%S')
# Out:
# '00:00:02'
